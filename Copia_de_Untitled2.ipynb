# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasVargas404/probabilidad/blob/main/Copia_de_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from statistics import *

# %%
# lista de calificaciones del grupo de probabilidad y estadistica

grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# la funcion type nos dice el tipo de datos de una variable
type(grupoa)
# Out:
# list

# %%
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
mediana = median(grupoa)
print(mediana)

# %%
moda = mode(grupoa)
print(moda)

# %%
moda2 = multimode(grupoa)
print(moda2)
